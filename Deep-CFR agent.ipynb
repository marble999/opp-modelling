# %% [markdown]
# ## Train Deep-CFR Agent for Leduc

# %%
import time, sys
from os.path import dirname, abspath

sys.path.append("/home/leduc/Deep-CFR/")

# %%
import numpy as np

from PokerRL.game.games import StandardLeduc  # or any other game

from DeepCFR.EvalAgentDeepCFR import EvalAgentDeepCFR
from DeepCFR.TrainingProfile import TrainingProfile
from DeepCFR.workers.driver.Driver import Driver

def generate_cfr_agent(n_iters=100):
    ctrl = Driver(t_prof=TrainingProfile(name="SD-CFR_LEDUC_EXAMPLE_"+str(n_iters),
                                         nn_type="feedforward",
                                         max_buffer_size_adv=3e6,
                                         eval_agent_export_freq=20,  # export API to play against the agent
                                         n_traversals_per_iter=1500,
                                         n_batches_adv_training=750,
                                         n_batches_avrg_training=2000,
                                         n_merge_and_table_layer_units_adv=64,
                                         n_merge_and_table_layer_units_avrg=64,
                                         n_units_final_adv=64,
                                         n_units_final_avrg=64,
                                         mini_batch_size_adv=2048,
                                         mini_batch_size_avrg=2048,
                                         init_adv_model="last",
                                         init_avrg_model="last",
                                         use_pre_layers_adv=False,
                                         use_pre_layers_avrg=False,

                                         game_cls=StandardLeduc,

                                         # You can specify one or both modes. Choosing both is useful to compare them.
                                         eval_modes_of_algo=(
                                             EvalAgentDeepCFR.EVAL_MODE_SINGLE,  # SD-CFR
                                             EvalAgentDeepCFR.EVAL_MODE_AVRG_NET,  # Deep CFR
                                         ),

                                         DISTRIBUTED=False,
                                         ),
                  eval_methods={
                      "br": 3,
                  },
                  n_iterations=n_iters)
    ctrl.run()
    ctrl.chief_handle.export_agent(step=ctrl.n_iterations) ## agent saved under poker_ai_data
    print("Saved agent.")

# %%
for n_iters in [200]:
    generate_cfr_agent(n_iters)
# Out:
#  ************************** Initing args for:  SD-CFR_LEDUC_EXAMPLE_200   **************************
# Creating Chief...
# Creating BR Evaluator...
# Tree with stack size [13, 13] has 464 nodes out of which 190 are non-terminal.
# Creating LAs...
# Creating Parameter Servers...
# Created and initialized Workers
# Setting stuff up...
# Starting Training...
# Iteration:  0
# Training Average Nets...
# Evaluating vs. BR
# Exporting agent
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  29.50255560874939s.   ||  Trained ADV 51.92070007324219s.   ||  Synced ADV 2.6526036262512207s.
#
# Trained AVRG 0.0s.   ||  Synced AVRG 0.0s.
#
# Iteration:  1
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  26.696146726608276s.   ||  Trained ADV 35.01076674461365s.   ||  Synced ADV 2.2355198860168457s.
#
# Iteration:  2
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  25.300901174545288s.   ||  Trained ADV 20.822120904922485s.   ||  Synced ADV 4.028051376342773s.
#
# Iteration:  3
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  29.34618616104126s.   ||  Trained ADV 21.30228042602539s.   ||  Synced ADV 2.522367238998413s.
#
# Trained AVRG 51.1947226524353s.   ||  Synced AVRG 6.443607330322266s.
#
# Iteration:  4
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  30.15848731994629s.   ||  Trained ADV 26.083407402038574s.   ||  Synced ADV 3.089935779571533s.
#
# Iteration:  5
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  35.074105739593506s.   ||  Trained ADV 44.31192684173584s.   ||  Synced ADV 2.9773945808410645s.
#
# Iteration:  6
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  35.52647137641907s.   ||  Trained ADV 25.388532400131226s.   ||  Synced ADV 2.281937837600708s.
#
# Trained AVRG 57.357807636260986s.   ||  Synced AVRG 6.272709608078003s.
#
# Iteration:  7
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  36.21823024749756s.   ||  Trained ADV 29.68695640563965s.   ||  Synced ADV 2.7868940830230713s.
#
# Iteration:  8
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  38.17025923728943s.   ||  Trained ADV 32.48137593269348s.   ||  Synced ADV 2.384884834289551s.
#
# Iteration:  9
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  35.44037437438965s.   ||  Trained ADV 23.335270643234253s.   ||  Synced ADV 2.5359511375427246s.
#
# Trained AVRG 61.2157723903656s.   ||  Synced AVRG 5.867464780807495s.
#
# Iteration:  10
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  37.14043211936951s.   ||  Trained ADV 23.06654644012451s.   ||  Synced ADV 4.674566984176636s.
#
# Iteration:  11
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  36.801138162612915s.   ||  Trained ADV 30.985229015350342s.   ||  Synced ADV 2.196016311645508s.
#
# Iteration:  12
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  35.74388122558594s.   ||  Trained ADV 27.41885232925415s.   ||  Synced ADV 2.3960049152374268s.
#
# Trained AVRG 69.78515648841858s.   ||  Synced AVRG 6.6151978969573975s.
#
# Iteration:  13
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  35.478074073791504s.   ||  Trained ADV 33.958205223083496s.   ||  Synced ADV 3.070038080215454s.
#
# Iteration:  14
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  36.49194574356079s.   ||  Trained ADV 19.719767570495605s.   ||  Synced ADV 2.8116214275360107s.
#
# Iteration:  15
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  35.52040505409241s.   ||  Trained ADV 32.83526539802551s.   ||  Synced ADV 2.2950165271759033s.
#
# Trained AVRG 62.213666677474976s.   ||  Synced AVRG 4.448745489120483s.
#
# Iteration:  16
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  29.613916397094727s.   ||  Trained ADV 23.21376395225525s.   ||  Synced ADV 2.35562801361084s.
#
# Iteration:  17
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  33.18670606613159s.   ||  Trained ADV 33.25238656997681s.   ||  Synced ADV 3.1376099586486816s.
#
# Iteration:  18
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  35.34934163093567s.   ||  Trained ADV 26.333251237869263s.   ||  Synced ADV 2.7113609313964844s.
#
# Trained AVRG 67.4902982711792s.   ||  Synced AVRG 6.463278293609619s.
#
# Iteration:  19
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  30.642893314361572s.   ||  Trained ADV 41.86970257759094s.   ||  Synced ADV 2.6159372329711914s.
#
# Iteration:  20
# Exporting agent
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  36.31266140937805s.   ||  Trained ADV 33.05399465560913s.   ||  Synced ADV 3.422966241836548s.
#
# Iteration:  21
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  33.44822454452515s.   ||  Trained ADV 35.802470445632935s.   ||  Synced ADV 2.7586615085601807s.
#
# Trained AVRG 65.98400926589966s.   ||  Synced AVRG 8.060266017913818s.
#
# Iteration:  22
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  33.57199716567993s.   ||  Trained ADV 19.14268970489502s.   ||  Synced ADV 2.230489730834961s.
#
# Iteration:  23
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  33.02543616294861s.   ||  Trained ADV 23.15825080871582s.   ||  Synced ADV 1.9584276676177979s.
#
# Iteration:  24
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  31.34698176383972s.   ||  Trained ADV 38.00226616859436s.   ||  Synced ADV 2.9643194675445557s.
#
# Trained AVRG 79.99724054336548s.   ||  Synced AVRG 6.265047788619995s.
#
# Iteration:  25
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  34.452099084854126s.   ||  Trained ADV 26.57880663871765s.   ||  Synced ADV 2.437235116958618s.
#
# Iteration:  26
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  32.65480017662048s.   ||  Trained ADV 30.234855890274048s.   ||  Synced ADV 2.588279962539673s.
#
# Iteration:  27
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  33.52480387687683s.   ||  Trained ADV 23.172931671142578s.   ||  Synced ADV 2.9212074279785156s.
#
# Trained AVRG 63.86507987976074s.   ||  Synced AVRG 8.305630683898926s.
#
# Iteration:  28
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  32.22255063056946s.   ||  Trained ADV 25.796475410461426s.   ||  Synced ADV 2.4366936683654785s.
#
# Iteration:  29
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  32.01690697669983s.   ||  Trained ADV 20.477790594100952s.   ||  Synced ADV 3.773080348968506s.
#
# Iteration:  30
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  31.77076292037964s.   ||  Trained ADV 26.2095685005188s.   ||  Synced ADV 4.035254716873169s.
#
# Trained AVRG 62.36689829826355s.   ||  Synced AVRG 5.68232798576355s.
#
# Iteration:  31
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  30.84980082511902s.   ||  Trained ADV 33.803837060928345s.   ||  Synced ADV 2.776512622833252s.
#
# Iteration:  32
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  32.168044090270996s.   ||  Trained ADV 29.230979204177856s.   ||  Synced ADV 2.8819522857666016s.
#
# Iteration:  33
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  30.449378490447998s.   ||  Trained ADV 20.411798238754272s.   ||  Synced ADV 1.9099094867706299s.
#
# Trained AVRG 74.74896788597107s.   ||  Synced AVRG 7.44106912612915s.
#
# Iteration:  34
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  30.029256343841553s.   ||  Trained ADV 24.165016174316406s.   ||  Synced ADV 2.5093600749969482s.
#
# Iteration:  35
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  30.86406707763672s.   ||  Trained ADV 38.620473861694336s.   ||  Synced ADV 1.9152958393096924s.
#
# Iteration:  36
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  31.74144148826599s.   ||  Trained ADV 31.485011100769043s.   ||  Synced ADV 2.4295098781585693s.
#
# Trained AVRG 70.31318211555481s.   ||  Synced AVRG 6.969525575637817s.
#
# Iteration:  37
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  30.31824827194214s.   ||  Trained ADV 47.893081188201904s.   ||  Synced ADV 3.2791974544525146s.
#
# Iteration:  38
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  31.213223218917847s.   ||  Trained ADV 21.92690348625183s.   ||  Synced ADV 1.9690508842468262s.
#
# Iteration:  39
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  32.4450204372406s.   ||  Trained ADV 48.04258918762207s.   ||  Synced ADV 3.2149784564971924s.
#
# Trained AVRG 75.45916938781738s.   ||  Synced AVRG 5.640636444091797s.
#
# Iteration:  40
# Exporting agent
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  35.97009515762329s.   ||  Trained ADV 33.6114387512207s.   ||  Synced ADV 2.4137191772460938s.
#
# Iteration:  41
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  33.90972137451172s.   ||  Trained ADV 45.12675356864929s.   ||  Synced ADV 3.6406779289245605s.
#
# Iteration:  42
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  34.22227430343628s.   ||  Trained ADV 21.751219034194946s.   ||  Synced ADV 2.437391996383667s.
#
# Trained AVRG 59.28360891342163s.   ||  Synced AVRG 5.8530192375183105s.
#
# Iteration:  43
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  32.63503980636597s.   ||  Trained ADV 35.187525510787964s.   ||  Synced ADV 2.3784549236297607s.
#
# Iteration:  44
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  31.953649520874023s.   ||  Trained ADV 29.676253080368042s.   ||  Synced ADV 2.573523759841919s.
#
# Iteration:  45
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  36.19801378250122s.   ||  Trained ADV 21.84253430366516s.   ||  Synced ADV 2.642338275909424s.
#
# Trained AVRG 77.02290797233582s.   ||  Synced AVRG 9.812114238739014s.
#
# Iteration:  46
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  34.24007177352905s.   ||  Trained ADV 23.232646942138672s.   ||  Synced ADV 3.714695692062378s.
#
# Iteration:  47
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  32.446332693099976s.   ||  Trained ADV 35.51694059371948s.   ||  Synced ADV 3.187849760055542s.
#
# Iteration:  48
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  32.44503450393677s.   ||  Trained ADV 24.318655967712402s.   ||  Synced ADV 2.9319403171539307s.
#
# Trained AVRG 54.10101103782654s.   ||  Synced AVRG 6.315504789352417s.
#
# Iteration:  49
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  32.709619760513306s.   ||  Trained ADV 28.88380241394043s.   ||  Synced ADV 2.915855646133423s.
#
# Iteration:  50
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  32.80039620399475s.   ||  Trained ADV 24.114280939102173s.   ||  Synced ADV 2.1594808101654053s.
#
# Iteration:  51
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  32.6098849773407s.   ||  Trained ADV 26.682167768478394s.   ||  Synced ADV 2.7858502864837646s.
#
# Trained AVRG 87.87719750404358s.   ||  Synced AVRG 5.680667161941528s.
#
# Iteration:  52
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  29.712727069854736s.   ||  Trained ADV 27.5656099319458s.   ||  Synced ADV 2.6581785678863525s.
#
# Iteration:  53
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  32.31649923324585s.   ||  Trained ADV 25.646711826324463s.   ||  Synced ADV 3.3137807846069336s.
#
# Iteration:  54
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  34.13128161430359s.   ||  Trained ADV 23.262643575668335s.   ||  Synced ADV 2.602081060409546s.
#
# Trained AVRG 79.71035861968994s.   ||  Synced AVRG 6.925496816635132s.
#
# Iteration:  55
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  34.73537611961365s.   ||  Trained ADV 27.02681851387024s.   ||  Synced ADV 2.7900774478912354s.
#
# Iteration:  56
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  32.928709268569946s.   ||  Trained ADV 69.0942656993866s.   ||  Synced ADV 4.44582986831665s.
#
# Iteration:  57
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  39.0911500453949s.   ||  Trained ADV 22.24217391014099s.   ||  Synced ADV 2.5652735233306885s.
#
# Trained AVRG 77.59618091583252s.   ||  Synced AVRG 7.768019437789917s.
#
# Iteration:  58
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  33.0065233707428s.   ||  Trained ADV 36.00723338127136s.   ||  Synced ADV 2.345832347869873s.
#
# Iteration:  59
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  35.578123807907104s.   ||  Trained ADV 36.0133159160614s.   ||  Synced ADV 2.7302112579345703s.
#
# Iteration:  60
# Training Average Nets...
# Evaluating vs. BR
# Exporting agent
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  31.596306085586548s.   ||  Trained ADV 28.559322834014893s.   ||  Synced ADV 2.4460225105285645s.
#
# Trained AVRG 60.87020540237427s.   ||  Synced AVRG 5.52241063117981s.
#
# Iteration:  61
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  28.691330432891846s.   ||  Trained ADV 26.094651222229004s.   ||  Synced ADV 2.451242685317993s.
#
# Iteration:  62
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  30.946945190429688s.   ||  Trained ADV 27.23231267929077s.   ||  Synced ADV 3.056887626647949s.
#
# Iteration:  63
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  28.396503686904907s.   ||  Trained ADV 48.8111138343811s.   ||  Synced ADV 3.141575813293457s.
#
# Trained AVRG 59.870991468429565s.   ||  Synced AVRG 5.635902166366577s.
#
# Iteration:  64
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  31.44264554977417s.   ||  Trained ADV 47.82368493080139s.   ||  Synced ADV 3.5683822631835938s.
#
# Iteration:  65
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  29.484286546707153s.   ||  Trained ADV 27.899842739105225s.   ||  Synced ADV 2.7796099185943604s.
#
# Iteration:  66
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  28.72630763053894s.   ||  Trained ADV 37.299344301223755s.   ||  Synced ADV 2.813385248184204s.
#
# Trained AVRG 55.4810631275177s.   ||  Synced AVRG 5.166134834289551s.
#
# Iteration:  67
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  28.028834104537964s.   ||  Trained ADV 52.814106702804565s.   ||  Synced ADV 3.1265883445739746s.
#
# Iteration:  68
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  29.2174551486969s.   ||  Trained ADV 47.367377519607544s.   ||  Synced ADV 3.0543265342712402s.
#
# Iteration:  69
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  29.958773136138916s.   ||  Trained ADV 31.11440873146057s.   ||  Synced ADV 3.447838544845581s.
#
# Trained AVRG 81.80950450897217s.   ||  Synced AVRG 6.0028157234191895s.
#
# Iteration:  70
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  30.8282208442688s.   ||  Trained ADV 37.81195783615112s.   ||  Synced ADV 2.840420722961426s.
#
# Iteration:  71
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  28.847625732421875s.   ||  Trained ADV 28.603469848632812s.   ||  Synced ADV 2.5801093578338623s.
#
# Iteration:  72
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  34.944591999053955s.   ||  Trained ADV 25.567007064819336s.   ||  Synced ADV 2.2606611251831055s.
#
# Trained AVRG 74.33879232406616s.   ||  Synced AVRG 5.348074197769165s.
#
# Iteration:  73
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  33.63424372673035s.   ||  Trained ADV 40.299885749816895s.   ||  Synced ADV 2.7454302310943604s.
#
# Iteration:  74
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  32.79619002342224s.   ||  Trained ADV 36.43665909767151s.   ||  Synced ADV 2.571838140487671s.
#
# Iteration:  75
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  29.296754121780396s.   ||  Trained ADV 33.80748987197876s.   ||  Synced ADV 2.246035099029541s.
#
# Trained AVRG 83.7460823059082s.   ||  Synced AVRG 6.40618109703064s.
#
# Iteration:  76
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  29.441888570785522s.   ||  Trained ADV 27.89240550994873s.   ||  Synced ADV 2.4786338806152344s.
#
# Iteration:  77
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  27.603943347930908s.   ||  Trained ADV 21.70674180984497s.   ||  Synced ADV 2.2749221324920654s.
#
# Iteration:  78
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  29.583157062530518s.   ||  Trained ADV 34.26729679107666s.   ||  Synced ADV 2.251789093017578s.
#
# Trained AVRG 77.41557025909424s.   ||  Synced AVRG 6.073881149291992s.
#
# Iteration:  79
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  31.56656503677368s.   ||  Trained ADV 22.031853437423706s.   ||  Synced ADV 2.304769992828369s.
#
# Iteration:  80
# Exporting agent
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  37.32823157310486s.   ||  Trained ADV 46.85735869407654s.   ||  Synced ADV 3.2627370357513428s.
#
# Iteration:  81
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  36.53571939468384s.   ||  Trained ADV 28.706424474716187s.   ||  Synced ADV 2.618495464324951s.
#
# Trained AVRG 55.789320945739746s.   ||  Synced AVRG 4.473767042160034s.
#
# Iteration:  82
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  30.479902029037476s.   ||  Trained ADV 28.657636404037476s.   ||  Synced ADV 2.4979896545410156s.
#
# Iteration:  83
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  26.950181245803833s.   ||  Trained ADV 34.13827633857727s.   ||  Synced ADV 2.35127854347229s.
#
# Iteration:  84
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  36.43402361869812s.   ||  Trained ADV 40.57626819610596s.   ||  Synced ADV 2.5398058891296387s.
#
# Trained AVRG 87.89163827896118s.   ||  Synced AVRG 7.117920875549316s.
#
# Iteration:  85
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  31.83078408241272s.   ||  Trained ADV 41.7766227722168s.   ||  Synced ADV 3.0770492553710938s.
#
# Iteration:  86
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  34.167261600494385s.   ||  Trained ADV 44.2295458316803s.   ||  Synced ADV 2.636768341064453s.
#
# Iteration:  87
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  33.17500185966492s.   ||  Trained ADV 22.02226161956787s.   ||  Synced ADV 2.3816750049591064s.
#
# Trained AVRG 72.38769793510437s.   ||  Synced AVRG 5.709819316864014s.
#
# Iteration:  88
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  34.04548907279968s.   ||  Trained ADV 39.279170513153076s.   ||  Synced ADV 2.8864808082580566s.
#
# Iteration:  89
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  32.96633696556091s.   ||  Trained ADV 53.95996427536011s.   ||  Synced ADV 3.8767788410186768s.
#
# Iteration:  90
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  33.73210954666138s.   ||  Trained ADV 46.26966381072998s.   ||  Synced ADV 3.568063974380493s.
#
# Trained AVRG 86.10880613327026s.   ||  Synced AVRG 6.602657079696655s.
#
# Iteration:  91
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  32.94008183479309s.   ||  Trained ADV 30.68826723098755s.   ||  Synced ADV 3.4421937465667725s.
#
# Iteration:  92
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  31.963698387145996s.   ||  Trained ADV 38.34966826438904s.   ||  Synced ADV 2.9498560428619385s.
#
# Iteration:  93
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  31.998739004135132s.   ||  Trained ADV 45.3326518535614s.   ||  Synced ADV 2.60433030128479s.
#
# Trained AVRG 85.8231692314148s.   ||  Synced AVRG 6.8149094581604s.
#
# Iteration:  94
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  33.21789360046387s.   ||  Trained ADV 31.488686561584473s.   ||  Synced ADV 2.7720093727111816s.
#
# Iteration:  95
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  34.241745471954346s.   ||  Trained ADV 39.26075005531311s.   ||  Synced ADV 2.6647610664367676s.
#
# Iteration:  96
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  33.39715886116028s.   ||  Trained ADV 33.255406856536865s.   ||  Synced ADV 3.0110456943511963s.
#
# Trained AVRG 73.79754400253296s.   ||  Synced AVRG 5.89207124710083s.
#
# Iteration:  97
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  32.70779633522034s.   ||  Trained ADV 37.660305976867676s.   ||  Synced ADV 2.852504014968872s.
#
# Iteration:  98
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  32.77982187271118s.   ||  Trained ADV 37.01314687728882s.   ||  Synced ADV 2.893364667892456s.
#
# Iteration:  99
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  33.486419916152954s.   ||  Trained ADV 41.184141397476196s.   ||  Synced ADV 2.4278199672698975s.
#
# Trained AVRG 69.93852162361145s.   ||  Synced AVRG 5.214478492736816s.
#
# Iteration:  100
# Exporting agent
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  34.302008867263794s.   ||  Trained ADV 48.91893005371094s.   ||  Synced ADV 3.810840368270874s.
#
# Iteration:  101
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  34.53471803665161s.   ||  Trained ADV 27.854181051254272s.   ||  Synced ADV 2.8214428424835205s.
#
# Iteration:  102
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  35.32085609436035s.   ||  Trained ADV 31.08341383934021s.   ||  Synced ADV 2.7048096656799316s.
#
# Trained AVRG 80.79847431182861s.   ||  Synced AVRG 6.618834972381592s.
#
# Iteration:  103
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  32.660871505737305s.   ||  Trained ADV 26.269724130630493s.   ||  Synced ADV 2.9730966091156006s.
#
# Iteration:  104
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  33.430975675582886s.   ||  Trained ADV 25.389476776123047s.   ||  Synced ADV 2.953864812850952s.
#
# Iteration:  105
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  30.94819402694702s.   ||  Trained ADV 43.23802065849304s.   ||  Synced ADV 3.034188985824585s.
#
# Trained AVRG 75.69285178184509s.   ||  Synced AVRG 5.881725788116455s.
#
# Iteration:  106
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  32.69512343406677s.   ||  Trained ADV 34.81506943702698s.   ||  Synced ADV 3.47294020652771s.
#
# Iteration:  107
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  30.05893039703369s.   ||  Trained ADV 25.95772647857666s.   ||  Synced ADV 3.1508429050445557s.
#
# Iteration:  108
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  32.710062742233276s.   ||  Trained ADV 37.36574172973633s.   ||  Synced ADV 4.2997283935546875s.
#
# Trained AVRG 68.32069230079651s.   ||  Synced AVRG 6.5336525440216064s.
#
# Iteration:  109
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  32.8555166721344s.   ||  Trained ADV 48.971972703933716s.   ||  Synced ADV 3.262209415435791s.
#
# Iteration:  110
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  32.10284471511841s.   ||  Trained ADV 36.57532477378845s.   ||  Synced ADV 4.020334005355835s.
#
# Iteration:  111
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  32.36847686767578s.   ||  Trained ADV 32.37871313095093s.   ||  Synced ADV 2.844620704650879s.
#
# Trained AVRG 79.12369060516357s.   ||  Synced AVRG 6.471120119094849s.
#
# Iteration:  112
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  30.198718547821045s.   ||  Trained ADV 36.52374053001404s.   ||  Synced ADV 2.6837317943573s.
#
# Iteration:  113
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  29.731200218200684s.   ||  Trained ADV 34.39716291427612s.   ||  Synced ADV 2.676964521408081s.
#
# Iteration:  114
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  31.63165545463562s.   ||  Trained ADV 34.31722116470337s.   ||  Synced ADV 2.732278823852539s.
#
# Trained AVRG 69.61266589164734s.   ||  Synced AVRG 6.362267732620239s.
#
# Iteration:  115
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  31.115998029708862s.   ||  Trained ADV 23.637717962265015s.   ||  Synced ADV 2.1600117683410645s.
#
# Iteration:  116
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  32.3732545375824s.   ||  Trained ADV 31.874014377593994s.   ||  Synced ADV 2.824505567550659s.
#
# Iteration:  117
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  29.983261346817017s.   ||  Trained ADV 36.935895919799805s.   ||  Synced ADV 2.745648145675659s.
#
# Trained AVRG 68.8947684764862s.   ||  Synced AVRG 6.550469398498535s.
#
# Iteration:  118
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  30.84218192100525s.   ||  Trained ADV 37.78275442123413s.   ||  Synced ADV 2.9959940910339355s.
#
# Iteration:  119
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  33.988422870635986s.   ||  Trained ADV 32.15340328216553s.   ||  Synced ADV 2.6640357971191406s.
#
# Iteration:  120
# Training Average Nets...
# Evaluating vs. BR
# Exporting agent
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  29.819146156311035s.   ||  Trained ADV 32.514493465423584s.   ||  Synced ADV 3.0308637619018555s.
#
# Trained AVRG 70.01772665977478s.   ||  Synced AVRG 6.179696083068848s.
#
# Iteration:  121
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  30.060114860534668s.   ||  Trained ADV 34.725990533828735s.   ||  Synced ADV 2.409860849380493s.
#
# Iteration:  122
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  32.823777198791504s.   ||  Trained ADV 29.980162620544434s.   ||  Synced ADV 2.257780075073242s.
#
# Iteration:  123
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  34.242764711380005s.   ||  Trained ADV 35.79939103126526s.   ||  Synced ADV 2.3160338401794434s.
#
# Trained AVRG 104.92668986320496s.   ||  Synced AVRG 7.388772487640381s.
#
# Iteration:  124
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  34.36822152137756s.   ||  Trained ADV 40.9697060585022s.   ||  Synced ADV 2.4841079711914062s.
#
# Iteration:  125
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  32.94235134124756s.   ||  Trained ADV 55.42709732055664s.   ||  Synced ADV 3.0127689838409424s.
#
# Iteration:  126
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  30.251599073410034s.   ||  Trained ADV 42.7046844959259s.   ||  Synced ADV 2.88909649848938s.
#
# Trained AVRG 58.97218990325928s.   ||  Synced AVRG 5.086429834365845s.
#
# Iteration:  127
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  36.17502021789551s.   ||  Trained ADV 31.080219507217407s.   ||  Synced ADV 2.517961263656616s.
#
# Iteration:  128
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  36.57201790809631s.   ||  Trained ADV 37.14094948768616s.   ||  Synced ADV 3.1320736408233643s.
#
# Iteration:  129
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  28.135152578353882s.   ||  Trained ADV 39.632221698760986s.   ||  Synced ADV 3.271144390106201s.
#
# Trained AVRG 78.58627367019653s.   ||  Synced AVRG 6.276195049285889s.
#
# Iteration:  130
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  28.127979278564453s.   ||  Trained ADV 35.16051459312439s.   ||  Synced ADV 2.7750484943389893s.
#
# Iteration:  131
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  35.11389207839966s.   ||  Trained ADV 41.34001088142395s.   ||  Synced ADV 2.9980995655059814s.
#
# Iteration:  132
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  28.46352219581604s.   ||  Trained ADV 26.875240802764893s.   ||  Synced ADV 2.8981802463531494s.
#
# Trained AVRG 78.69250798225403s.   ||  Synced AVRG 6.246240615844727s.
#
# Iteration:  133
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  33.80046343803406s.   ||  Trained ADV 31.45366334915161s.   ||  Synced ADV 3.243406057357788s.
#
# Iteration:  134
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  34.06990122795105s.   ||  Trained ADV 34.16755247116089s.   ||  Synced ADV 2.805849552154541s.
#
# Iteration:  135
# Training Average Nets...
# Evaluating vs. BR
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  33.00867438316345s.   ||  Trained ADV 31.66753625869751s.   ||  Synced ADV 2.260820150375366s.
#
# Trained AVRG 66.00385475158691s.   ||  Synced AVRG 6.34670615196228s.
#
# Iteration:  136
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Generating Data...
# Training Advantage Net...
# Pushing new net to chief...
# Synchronizing...
# Generating Data:  33.31696438789368s.   ||  Trained ADV 30.736140966415405s.   ||  Synced ADV 2.4811582565307617s.
#
# Iteration:  137
# Generating Data...
